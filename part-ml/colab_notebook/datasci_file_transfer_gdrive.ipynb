# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from distutils.dir_util import copy_tree
copy_tree("/content/drive/Shareddrives/Datasci/bkk_radar_images", "/content/radar_image")
# Out:
# ['/content/radar_image/bkk_radar_images_1.zip',
#  '/content/radar_image/bkk_radar_images_8.zip',
#  '/content/radar_image/bkk_radar_images_9.zip',
#  '/content/radar_image/bkk_radar_images_2.zip',
#  '/content/radar_image/bkk_radar_images_4.zip',
#  '/content/radar_image/bkk_radar_images_3.zip',
#  '/content/radar_image/bkk_radar_images_7.zip',
#  '/content/radar_image/bkk_radar_images_5.zip',
#  '/content/radar_image/bkk_radar_images_6.zip',
#  '/content/radar_image/sample_1607928702.png',
#  '/content/radar_image/bkk_radar_images_10.zip',
#  '/content/radar_image/bkk_radar_images_11.zip',
#  '/content/radar_image/bkk_radar_images_12.zip',
#  '/content/radar_image/bkk_radar_images_13.zip',
#  '/content/radar_image/README.txt']

# %%
# !unzip "/content/radar_image/bkk_radar_images_1.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_2.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_3.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_4.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_5.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_6.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_7.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_8.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_9.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_10.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_11.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_12.zip" -d "/content/radar_image"
# !unzip "/content/radar_image/bkk_radar_images_13.zip" -d "/content/radar_image"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/radar_image/bkk_radar_images_13/1622777542.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622778148.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622778434.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622779338.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622780250.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622780848.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622781134.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622781740.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622782042.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622782936.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622784150.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622784440.png
#   inflating: /content/radar_image/bkk_radar_images_13/1622784748.png
# ...

# %%
copy_tree("/content/radar_image/bkk_radar_images_1", "/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all")
# Out:
# ['/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593245198.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593658002.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593249398.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593063094.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593098792.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1594158398.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593840700.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1592856092.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593644796.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593337290.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1593596794.png',
# ...

# %%
copy_tree("/content/radar_image/bkk_radar_images_2", "/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all")
# Out:
# ['/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1595520296.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1594491688.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1595052398.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1594838142.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1595335588.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1594961452.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1595265656.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1595488966.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1595059666.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1595770286.png',
#  '/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all/1594970210.png',
# ...

# %%
for i in range(3,14):
  copy_tree(f"/content/radar_image/bkk_radar_images_{i}", "/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all")

# %%
import os

# %%
path, dirs, files = next(os.walk('/content/drive/Shareddrives/Datasci/Dataset/bkk_radar_images_all'))
file_count = len(files)
print(file_count)
# Out:
# 86083
